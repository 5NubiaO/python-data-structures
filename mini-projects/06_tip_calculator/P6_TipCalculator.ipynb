# %% [markdown]
# <a href="https://colab.research.google.com/github/5NubiaO/python-data-structures/blob/main/mini-projects/06_tip_calculator/P6_TipCalculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This program calculates the tip amount of a bill

def tipcalculator(bill,percentage,people):
  global total,tip,split
  tip = round(bill*(percentage/100),2)
  total = bill+tip
  split = total/people
  return tip,total,split

bill = float (input('What was the total of the bill? '))
percentage = float(input('How much % would you like to give? '))
people = float(input('How may people to split the bill with? '))

tipcalculator(bill,percentage,people)
print('The total amount is: ' +str(total))
print('The tip is: '+ str(tip))
print('Each person should give: '+str(split))
# Out:
# What was the total of the bill? 120.50
# How much % would you like to give? 15
# How may people to split the bill with? 3
# The total amount is: 138.57
# The tip is: 18.07
# Each person should give: 46.19

# %%
#A better version of the programm:

#This program calculates the tip amount of a bill

def tipcalculator(bill,percentage,people):
  tip = round(bill*(percentage/100),2)
  total = bill+tip
  split = total/people
  return total,tip,split

bill = float (input('What was the total of the bill? '))
percentage = float(input('How much % would you like to give? '))
people = float(input('How may people to split the bill with? '))

total, tip,split = tipcalculator(bill,percentage,people)
print(f'The total amount is: ${total}')
print('The tip is: '+ str(tip))
print('Each person should give: '+str(split))
# Out:
# What was the total of the bill? 120.5
# How much % would you like to give? 15
# How may people to split the bill with? 3
# The total amount is: $138.57
# The tip is: 18.07
# Each person should give: 46.19

# %%
#Task 1 Define Simple Functions
def greet(name):
  print('Hello, '+name)

name = input('What is your name?: ')
greet(name)
# Out:
# What is your name?: Nubia
# Hello, Nubia

# %%
def  multiply(a,b):
  return a*b

a = float(input('Introduce First Number please: '))
b = float(input('Introduce Second Number please: '))
multiply(a,b)
# Out:
# Introduce First Number please: 4
# Introduce Second Number please: 3
# 12.0

# %%
#Task 2 Write a for loop
for i in range (5):
  print('Hello')
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
#Task 3 for loop and name

def say_hello(name):
  for i in range(5):
    print('Hello, '+name)

name =input('What is your name? : ')
say_hello(name)
# Out:
# What is your name? : nubia
# Hello, nubia
# Hello, nubia
# Hello, nubia
# Hello, nubia
# Hello, nubia
