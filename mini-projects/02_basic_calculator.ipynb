# %% [markdown]
# <a href="https://colab.research.google.com/github/5NubiaO/python-data-structures/blob/main/mini-projects/02_basic_calculator/P2_BasicCalculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This is a Basic Calculator on Python
a = 0
b = 0

while True:
  try:
    print('Hi ^^, Please Type First Number')
    a = float(input())
    break
  except: print('Invalid Input')


while True:
  try:
    print('Second number')
    b = float(input())
    break
  except: print('Invalid Input')

while True:

  print('What do you wanna do today? ')
  print('Type +, -, *, /, finish')
  op = input()
  if op == '+':
    print(a+b)
  elif op == '-':
    print(a-b)
  elif op == '*':
    print(a*b)
  elif op == '/':
    if b == 0:
      print('Cannot Divide by zero')
    else:
      print(a/b)
  elif op == 'finish':
    print('Bye ^^')
    break
  else:
    print('Invalid Operation')
    continue
# Out:
# Hi ^^, Please Type First Number
# r
# Invalid Input
# Hi ^^, Please Type First Number
# ^
# Invalid Input
# Hi ^^, Please Type First Number
# 3.3
# Second number
# @
# Invalid Input
# Second number
# w
# Invalid Input
# Second number
# 6
# What do you wanna do today?
# Type +, -, *, /, finish
# +
# 9.3
# What do you wanna do today?
# Type +, -, *, /, finish
# -
# -2.7
# What do you wanna do today?
# Type +, -, *, /, finish
# *
# 19.799999999999997
# What do you wanna do today?
# Type +, -, *, /, finish
# /
# 0.5499999999999999
# What do you wanna do today?
# Type +, -, *, /, finish
# finish
# Bye ^^
