# %% [markdown]
# <a href="https://colab.research.google.com/github/5NubiaO/python-data-structures/blob/main/mini_projects/04_guess_number/P04_GuessTheNumber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This is a guess the number game

import random
secretNumber = random.randint(1,20)
print('I am thinking of a number between 1 and 20')

#ask the player to guess 6 times
for guessesTaken in range(1,7):
    print('Take a guess')
    guess = int(input())

    if guess < secretNumber:
        print('Your guess is too Low')
    elif guess > secretNumber:
        print('Your guess is too High')
    else:
      break #This condition is thne correct guess!

if guess == secretNumber:
  print('Good job! You guessed my number in ' + str(guessesTaken)+ '  guesses!')
else:
  print('Nope. The number I was thinking of was '+str(secretNumber))
# Out:
# I am thinking of a number between 1 and 20
# Take a guess
# 15
# Your guess is too High
# Take a guess
# 10
# Good job! You guessed my number in 2guesses!
